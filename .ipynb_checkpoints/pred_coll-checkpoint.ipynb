# %%
from utils.predictions_content import *
from utils.predictions_notes import *
from utils.collaborative import *
from collections import OrderedDict
# Out:
# /Users/constancescherer/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#path = "/Vrac/PLDAC_addic7ed/ratings/ratings_imdb/users"
path_ratings = "/Users/constancescherer/Desktop/ratings/ratings_imdb/users"
path_d_user = "/Users/constancescherer/Desktop/pickles/d_user.p"
#d_user= get_d_user(path)
with open(path_d_user, 'rb') as pickle_file:
    d_user = pickle.load(pickle_file)

liste_series = get_liste_series(d_user)
data = get_data(d_user)
all_data, num_user, num_item = get_all_data(data)
train, train_mat, test = get_train_test(num_user, num_item, all_data, test_size=20)
mean, u_means, i_means,U_ksvd, I_ksvd =  get_Uksvd_Iksvd(train, train_mat, num_user, num_item)
d_username_id, d_itemname_id, Full = create_sparse_mat(data)

path_series = "/Users/constancescherer/Desktop/addic7ed_final"
#path_series = '/Vrac/PLDAC_addic7ed/addic7ed_clean'
d_info, d_name = getDicts(path_series)
d_ind = reverse_dict(d_name)
d_titre_filename = get_d_titre_filename("titles/title-filename.txt")
d_filename_titre = reverse_dict(d_titre_filename)
d_id_username = reverse_dict(d_username_id)
d_id_serie = reverse_dict(d_itemname_id)

# %%
d_serie = dict()
for username, d_s in d_user.items() :
    for serie, rating in d_s.items() :
        if serie in d_serie.keys() :
            d_serie[serie] += 1
        else :
            d_serie[serie] = 1

# %%
d_serie['aidan-5']
# Out:
# 1

# %%
d_user['poe-48833']
# Out:
# {'blade-of-the-immortal': 10.0,
#  'detectorists': 10.0,
#  'the-civil-war': 10.0,
#  'the-walking-dead': 9.0,
#  'the-x-files': 10.0}

# %%
d_user['ADtheThird']
# Out:
# {'banshee': 9.0,
#  'castle': 10.0,
#  'common': 8.0,
#  'common-law': 8.0,
#  'continuum': 7.0,
#  'psych': 10.0,
#  'the-vampire-diaries': 9.0}

# %%
username = 'ADtheThird'

# %%
uid = d_username_id[username]
d_notes = dict()
for serie, iid in d_itemname_id.items() :
    if serie not in d_user[username].keys() :
        # prediction
        p = pred_func_ksvd(uid, iid, U_ksvd, I_ksvd, u_means, i_means, mean)
        if p > 10 :
            p = 10
        d_notes[serie] = p

# %%
d_notes
# Out:
# {'boardwalk-empire': 9.922663800375801,
#  'game-of-thrones': 9.341958528594041,
#  'episodes': 9.004329953874858,
#  'american-horror-story': 8.017820267211224,
#  'shameless': 9.207699345237941,
#  'being-human': 7.084976801796564,
#  'ray-donovan': 9.044885226658412,
#  'masters-of-sex': 7.810643185350231,
#  'the-affair': 7.586316640036446,
#  'empire': 9.811399462315942,
#  'last-week-tonight-with-john-oliver': 10,
#  'the-good-wife': 9.499750252056838,
#  'the-walking-dead': 8.136784546833997,
#  'terra-nova': 7.401110634851297,
#  'the-shield': 10,
#  'homeland': 8.640592219746711,
#  'lost': 8.653831310697182,
#  'breaking-bad': 10,
#  'nova': 7.453645557710975,
#  'rectify': 9.153507448871682,
#  'under-the-dome': 6.239651543753487,
#  'true-detective': 9.094773360661097,
#  'two-and-a-half-men': 7.147281877888449,
#  'cambridge-spies': 9.409294469015938,
#  'empire-falls': 8.191479399964049,
#  'profiler': 7.408058507101876,
#  'angels-in-america': 8.9171177646092,
#  'csi-miami': 6.777888108813572,
#  'the-west-wing': 9.82571332995631,
#  'alias': 7.792344592866443,
#  'touching-evil': 9.326522849854967,
#  'jack-the-ripper': 9.865828091757637,
#  'band-of-brothers': 10,
#  'the-sopranos': 10,
#  'csi-crime-scene-investigation': 8.859183881648633,
#  'the-wire': 10,
#  'brothers': 10,
#  'daniel-deronda': 9.94618034362793,
#  'the-closer': 9.328526519593737,
#  'californication': 8.294325215475899,
#  'moonlighting': 8.955071122305732,
#  'vikings': 8.861354866094288,
#  'demons': 8.89343398481935,
#  'quantico': 6.672060903612073,
#  'i-just-want-my-pants-back': 8.157907826559883,
#  'fresh-meat': 9.05993343080793,
#  'touch': 7.841679595765613,
#  'unsupervised': 9.658421380179268,
#  'awake': 8.38895996514853,
#  'arrested-development': 9.894661438288946,
#  'the-adventures-of-brisco-county-jr': 10,
#  'prison-break': 9.476907339114732,
#  'deadwood': 9.951426982879639,
#  'invasion': 8.58288390295846,
#  'doc-martin': 9.62481909912902,
#  'the-dead-zone': 9.122915565193473,
#  'burn-notice': 9.702711732046945,
#  'samurai-champloo': 10,
#  'smallville': 8.28293893101451,
#  'lost-girl': 7.604041735331217,
#  'i-dream-of-jeannie': 9.632244863964262,
#  'zorro': 10,
#  'bewitched': 9.346905315315329,
#  'the-larry-sanders-show': 10,
#  'spartacus-gods-of-the-arena': 9.284625394003731,
#  'night-stalker': 9.533667836870464,
#  'threshold': 7.858973080771309,
#  'wild-west': 10,
#  'saving-grace': 8.64934812273298,
#  'the-voice': 7.978330762045723,
#  'injustice': 9.231753008706228,
#  'the-nine-lives-of-chloe-king': 7.6746324130467,
#  'suits': 8.850763025737944,
#  'awkward': 8.785137108394078,
#  'iron-man': 8.14759383882795,
#  'avatar-the-last-airbender': 10,
#  'the-secret-circle': 8.19307978413686,
#  'person-of-interest': 9.617230006626674,
#  'grimm': 8.594645659128824,
#  'once-upon-a-time': 8.009983787137871,
#  'kolchak-the-night-stalker': 9.526386696951729,
#  'dead-like-me': 8.34503194264003,
#  'the-wild-wild-west': 10,
#  'kung-fu': 10,
#  'touched-by-an-angel': 10,
#  'medium': 10,
#  'corner-gas': 10,
#  'the-nine': 7.6746324130467,
#  'hatfields-mccoys': 8.694180892762683,
#  'longmire': 9.14041408635504,
#  'line-of-duty': 10,
#  'major-crimes': 7.837038212463635,
#  'elementary': 8.304199312099072,
#  'the-bletchley-circle': 9.066084248679024,
#  'coupling': 10,
#  'hunted': 7.756667184305714,
#  'arrow': 7.409670768331746,
#  'utopia': 10,
#  'intelligence': 6.159636838095528,
#  'broadchurch': 9.515729498418962,
#  'fringe': 9.509883432371485,
#  'merlin': 8.743109166281563,
#  'beware-the-batman': 9.569723851340157,
#  'dollhouse': 8.46225333895002,
#  'bron-broen': 10,
#  'the-blacklist': 8.223972502208891,
#  'star-trek-voyager': 8.617218835013253,
#  'iron-man-armored-adventures': 7.975329580761136,
#  'top-of-the-lake': 7.600267464773995,
#  'salem': 7.417429497523337,
#  'penny-dreadful': 8.255882570896242,
#  'caprica': 8.680715939658029,
#  'halt-and-catch-fire': 8.596663679395402,
#  'the-last-ship': 7.990581266172639,
#  'have-gun-will-travel': 10,
#  'the-flash': 7.702630448879155,
#  'heroes-reborn': 6.440537503047018,
#  'gracepoint': 6.500758338284182,
#  'constantine': 7.340518542698451,
#  'better-call-saul': 9.413947548616212,
#  'hand-of-god': 7.6490343638828815,
#  'dig': 8.891592439714369,
#  'joan-of-arcadia': 7.479950132824125,
#  'sense8': 8.509238250489489,
#  'daredevil': 9.458408299582345,
#  'jonathan-strange-mr-norrell': 9.64246926988874,
#  'supergirl': 6.553759109957372,
#  'scream-queens': 8.041753178551083,
#  'humans': 8.91768015305508,
#  'scream': 7.872762884412492,
#  'warehouse-13': 8.057231879033962,
#  'witchblade': 8.988137903667631,
#  'the-prisoner': 10,
#  'quantum-leap': 9.031030450548442,
#  'primeval': 7.738677452136943,
#  'the-lost-room': 10,
#  'human-target': 9.051498658316476,
#  'justified': 10,
#  'the-x-files': 9.442261146838222,
#  'luther': 9.244574757365436,
#  'strike-back': 8.65919152998821,
#  'x-men': 10,
#  'last-comic-standing': 9.159907681601387,
#  'jekyll': 9.435079544309584,
#  'freaks-and-geeks': 10,
#  'that-70s-show': 9.648260934012276,
#  'that-80s-show': 5.407351834433419,
#  'the-fresh-prince-of-bel-air': 10,
#  'how-to-get-away-with-murder': 7.147856394449869,
#  'happy-town': 10,
#  'the-a-team': 8.966252190726143,
#  'outlaw': 10,
#  'family-matters': 7.962596757071358,
#  'batman-beyond': 9.757127512068974,
#  'the-oblongs': 9.150001389639717,
#  'full-house': 8.444728021497848,
#  'spawn': 10,
#  'night-court': 10,
#  'newsradio': 10,
#  'the-mighty-boosh': 8.36982032230922,
#  'the-big-bang-theory': 8.296389599873812,
#  'the-dukes-of-hazzard': 9.785220486777169,
#  'metalocalypse': 10,
#  'aqua-teen-hunger-force': 10,
#  'batman-the-animated-series': 10,
#  'thundercats': 10,
#  'pawn-stars': 7.725858075278145,
#  'cheers': 10,
#  'knight-rider': 10,
#  'alf': 10,
#  'batman': 10,
#  'tales-from-the-crypt': 10,
#  'wonder-woman': 9.249135569920615,
#  'king-of-the-hill': 9.093199697340497,
#  'the-incredible-hulk': 8.763914869613005,
#  'twilight-zone': 10,
#  'the-twilight-zone': 10,
#  'scooby-doo-where-are-you-': 9.249235705723837,
#  'columbo': 10,
#  'the-invaders': 10,
#  'night-gallery': 9.860660590134657,
#  'sliders': 8.97593128812182,
#  'the-equalizer': 9.328630946931384,
#  'fawlty-towers': 10,
#  'the-addams-family': 9.989194543021066,
#  'millennium': 10,
#  'sherlock-holmes': 10,
#  'v-the-final-battle': 9.802697113582065,
#  'the-fugitive': 10,
#  'the-lone-gunmen': 8.992489042736235,
#  'star-trek': 9.74907535436202,
#  'desperate-housewives': 9.07879149855064,
#  'ducktales': 10,
#  'star-trek-the-next-generation': 9.74858182790328,
#  'sabrina-the-teenage-witch': 8.72565093721662,
#  'fastlane': 7.984209719158353,
#  'keeping-up-with-the-kardashians': 4.6894935199192584,
#  'gossip-girl': 8.30223801022484,
#  'the-bachelor': 3.6590913363865436,
#  'jessie': 6.872702311752433,
#  'jem': 10,
#  'party-of-five': 9.267221409933907,
#  'my-so-called-life': 10,
#  'roseanne': 9.735879126049223,
#  'the-fosters': 9.31950414987435,
#  'tru-calling': 7.853014523642403,
#  'jane-the-virgin': 8.670550686972481,
#  'izombie': 8.92924658580176,
#  'melrose-place': 10,
#  'cougar-town': 7.350034958975655,
#  'the-bachelorette': 4.498157682872954,
#  'gcb': 4.660436494009835,
#  'unbreakable-kimmy-schmidt': 7.601047435076133,
#  'the-dovekeepers': 4.65577254976545,
#  'ad-the-bible-continues': 8.88019299128699,
#  'the-slap': 7.657630307333809,
#  'deception': 7.127059037344796,
#  'deadbeat': 8.411973340170723,
#  'undateable': 7.440293281797378,
#  'marry-me': 5.457728535788399,
#  'wayward-pines': 7.779714240790893,
#  'the-whispers': 6.821829341706775,
#  'aquarius': 8.735358419872465,
#  'togetherness': 9.876054044753785,
#  'one-big-happy': 6.1569360324314655,
#  '12-monkeys': 8.38902491614932,
#  'the-messengers': 5.544577366965157,
#  'battle-creek': 8.478000164031982,
#  'the-last-man-on-earth': 7.599478565916723,
#  'man-seeking-woman': 9.99909800574893,
#  'the-odd-couple': 6.776813295550812,
#  'secrets-and-lies': 7.132537705557686,
#  'bloodline': 8.18667609700353,
#  'powers': 6.735639753795804,
#  'weird-loners': 6.905142171042305,
#  'younger': 9.488140287853422,
#  'american-odyssey': 7.069317469521174,
#  'the-lizzie-borden-chronicles': 5.577805541810534,
#  'your-family-or-mine': 4.6583398410252155,
#  'mr-robot': 7.507353101457867,
#  'the-brink': 9.109738894871303,
#  'complications': 8.66707740511213,
#  'mr-robinson': 6.908851487295967,
#  'stitchers': 5.925045137281541,
#  'dark-matter': 8.079579392770178,
#  'clipped': 8.157991749899727,
#  'impastor': 9.826513313111803,
#  'grandfathered': 8.860083634512765,
#  'the-grinder': 9.537137008848644,
#  'blindspot': 6.600554941799441,
#  'limitless': 7.909078175680977,
#  'significant-mother': 6.402325970785958,
#  'difficult-people': 8.989688578106108,
#  'sneaky-pete': 9.650244099753243,
#  'lucifer': 8.788491705279329,
#  'kevin-from-work': 5.992695513225736,
#  'documentary-now-': 6.155134541647774,
#  'casual': 6.633393628256661,
#  'i-claudius': 10,
#  'ultraviolet': 10,
#  'flash-gordon': 6.735792341686429,
#  'battlestar-galactica': 9.045839286985851,
#  'torchwood': 8.350705617434018,
#  'centennial': 10,
#  'vice': 10,
#  'magnum-pi': 9.82459949661087,
#  'miami-vice': 10,
#  'sherlock': 9.848157937186103,
#  'blackadder': 10,
#  'supernatural': 10,
#  'better-off-ted': 10,
#  'party-down': 9.467787415640693,
#  'perry-mason': 10,
#  'ironside': 8.894649369376046,
#  'all-in-the-family': 10,
#  'bonanza': 8.710568132854643,
#  'spongebob-squarepants': 8.860485559538866,
#  'the-street': 10,
#  'red-dwarf': 10,
#  'friends': 9.197119783055975,
#  'twin-peaks': 9.867664433522506,
#  'dallas': 8.028743130820137,
#  'the-munsters': 9.908172948019844,
#  'walking-with-monsters': 10,
#  'frasier': 10,
#  'real-time-with-bill-maher': 9.645841462271553,
#  'homicide-life-on-the-street': 10,
#  'buffy-the-vampire-slayer': 10,
#  'saturday-night-live': 7.239004419631316,
#  'the-fall-and-rise-of-reginald-perrin': 10,
#  'the-seventies': 7.950188636779784,
#  'seinfeld': 10,
#  'angel': 10,
#  'the-winds-of-war': 10,
#  'law-order-trial-by-jury': 9.231666524069649,
#  'earth-final-conflict': 7.766502816336494,
#  'the-newsroom': 8.463666779654366,
#  'no-heroics': 7.656842572348458,
#  'selfie': 7.154327256338936,
#  'red-band-society': 9.028280121939522,
#  'black-ish': 7.919055325644356,
#  'cristela': 8.15791116441999,
#  'black-jesus': 9.55154219884721,
#  'black-mirror': 9.48877007225779,
#  'eve': 8.235145527975899,
#  'girls': 8.680523259299141,
#  'bunheads': 7.320867084321521,
#  'gilmore-girls': 8.680265290396553,
#  'broad-city': 7.164272648947579,
#  'inside-amy-schumer': 7.450888800930667,
#  'darkwing-duck': 10,
#  'jeeves-and-wooster': 10,
#  'war-and-peace': 6.990777674175443,
#  'the-benny-hill-show': 10,
#  'the-thin-blue-line': 8.910197598593575,
#  'the-simpsons': 9.950138721631202,
#  'teenage-mutant-ninja-turtles': 8.896700722830635,
#  'digimon-digital-monsters': 9.91018567766462,
#  'steven-universe': 9.793794288398315,
#  'over-the-garden-wall': 10,
#  'xxxholic': 8.658390385763985,
#  'drake-josh': 10,
#  'pushing-daisies': 9.284843376704625,
#  'las-vegas': 7.9159201213291706,
#  'hawaii-five-0': 8.13808440133889,
#  'x-men-evolution': 8.764436532580662,
#  'malcolm-in-the-middle': 10,
#  'doctor-who': 9.183791524441816,
#  'zen': 10,
#  'moonlight': 9.522413706579128,
#  'csi-ny': 9.6411212512425,
#  'camelot': 7.660704476492745,
#  'the-borgias': 9.002729146139963,
#  'justice': 10,
#  'campus': 10,
#  'the-crimson-petal-and-the-white': 10,
#  'the-flintstones': 10,
#  'the-batman': 8.66346011843,
#  'hercules-the-legendary-journeys': 10,
#  'without-a-trace': 8.077191121237618,
#  'jackie-chan-adventures': 10,
#  'firefly': 10,
#  'goosebumps': 9.657102448599678,
#  'justice-league': 10,
#  'heartland': 9.42160049165998,
#  'vegas': 8.666191918509346,
#  'young-dracula': 10,
#  'beast-wars-transformers': 10,
#  '90210': 7.741368729727608,
#  'evolution': 8.764436532580662,
#  'true-blood': 8.129356698866014,
#  'privileged': 6.400668007986885,
#  'in-plain-sight': 8.525057179587227,
#  'the-mentalist': 9.763246822357177,
#  'the-oc': 9.754733939747233,
#  'eastenders': 5.729109094924285,
#  'the-unit': 7.651481969015938,
#  'underbelly': 8.934411525726318,
#  'the-sarah-jane-adventures': 7.647534711020333,
#  'glee': 8.740873391287668,
#  'xena-warrior-princess': 9.78388009752546,
#  'everybody-hates-chris': 9.23644513175601,
#  'hotel-babylon': 9.494895163036528,
#  'dark-blue': 5.43490377153669,
#  'the-take': 9.661163670676094,
#  'bonekickers': 5.823717616853259,
#  'criminal-justice': 9.658126694815499,
#  'charmed': 8.484731496491047,
#  'flashforward': 8.35391160420009,
#  'modern-family': 8.058393071011668,
#  'the-middle': 9.8611452011835,
#  'one-tree-hill': 10,
#  'survivors': 8.115444957435905,
#  'dexter': 10,
#  'numb3rs': 8.7703125968812,
#  'whose-line-is-it-anyway-': 10,
#  'the-new-batman-adventures': 10,
#  'the-13-ghosts-of-scooby-doo': 8.438396423582045,
#  'samurai-jack': 10,
#  'the-adventures-of-tintin': 10,
#  'wolverine': 9.988612356640044,
#  'teen-titans': 10,
#  'the-spectacular-spider-man': 10,
#  'the-powerpuff-girls': 8.46610036577497,
#  'powerpuff-girls': 8.349536508545839,
#  'cockroaches': 8.666159493582589,
#  'wolverine-and-the-x-men': 9.502702209975691,
#  'the-tick': 8.892929014268812,
#  'king-of-the-nerds': 6.330482982453845,
#  'the-middleman': 9.455436379568916,
#  'stargate-universe': 7.3256966774099554,
#  'criminal-minds': 7.937814576285225,
#  'parents': 7.826426051911853,
#  'victorious': 9.396028604961575,
#  'cops': 8.01653835370943,
#  'heroes': 8.704456232191527,
#  'just-shoot-me': 9.21580894409664,
#  'carnivale': 10,
#  '7th-heaven': 5.471782851528811,
#  'surface': 8.661158425467354,
#  'wire-in-the-blood': 8.961940438406806,
#  'hannibal': 8.980365903036933,
#  'the-bastard-executioner': 7.254580456869942,
#  'taken': 7.466829322633289,
#  'family-guy': 9.04948153974075,
#  'how-i-met-your-mother': 8.550051041518184,
#  'downton-abbey': 8.967863279323641,
#  'friday-night-lights': 10,
#  'the-sarah-silverman-program': 7.484035408686077,
#  'eureka': 9.217872483389717,
#  'house-of-cards': 8.717704539960462,
#  'house': 8.654071070392678,
#  'boss': 9.470176560538155,
#  'the-following': 7.074527869148859,
#  'bates-motel': 8.763868942023803,
#  'the-killer-speaks': 10,
#  'power': 9.103895718710763,
#  'csi-cyber': 5.414160592215401,
#  'zoo': 5.750186429704938,
#  'between': 5.651120049612862,
#  'community': 9.528041110926376,
#  'beauty-and-the-beast': 7.512642247336251,
#  'city-hunter': 8.362688745771134,
#  'the-beast': 7.578800511250297,
#  'sons-of-anarchy': 8.710844592442587,
#  'believe': 6.973661286490303,
#  'tyrant': 7.957569272177559,
#  'fortitude': 7.161828802413298,
#  'code-black': 8.16083270233947,
#  'covert-affairs': 8.278728482382636,
#  'dci-banks': 8.324789069947741,
#  'whitechapel': 9.008932295299712,
#  'rome': 10,
#  'narcos': 10,
#  'drunk-history': 7.227027968754843,
#  'dekalog': 10,
#  'father-ted': 10,
#  'the-cosby-show': 10,
#  'only-fools-and-horses': 10,
#  'six-feet-under': 10,
#  'the-it-crowd': 10,
#  'the-vicar-of-dibley': 9.94804334640503,
#  'peep-show': 10,
#  'curb-your-enthusiasm': 10,
#  'the-wonder-years': 10,
#  'south-park': 9.417376819655386,
#  'boy-meets-world': 9.110765702383858,
#  'american-dad': 8.948427257390556,
#  'family-ties': 10,
#  'house-of-lies': 6.929581766004685,
#  'scrubs': 9.631454321802877,
#  'storage-wars': 6.657417161124092,
#  'hello-ladies': 8.147566182272774,
#  'farscape-the-peacekeeper-wars': 10,
#  'the-simple-life': 5.657872063773018,
#  'back-to-you': 10,
#  'whitney': 5.950297802213638,
#  'the-war-at-home': 6.756280127025785,
#  'babylon-5': 9.7229280169048,
#  'are-you-there-chelsea-': 6.908396584647042,
#  'stargate-infinity': 2.6620510646275104,
#  'babylon': 9.674848897116524,
#  'the-marriage-ref': 5.659182889120919,
#  'raising-hope': 10,
#  'mad-men': 9.47651009126143,
#  'mad': 9.464538573377766,
#  'comic-book-men': 8.398964268820626,
#  'the-boondocks': 10,
#  'the-paradise': 8.518132482256206,
#  'lilyhammer': 9.664347512381417,
#  'jericho': 9.373797621045792,
#  'helix': 7.128009659903389,
#  'happy-valley': 10,
#  'manhattan': 8.15403686250959,
#  'stalker': 8.548694348873052,
#  'in-search-of-aliens': 10,
#  'scorpion': 6.6051409484631,
#  'killjoys': 8.33068039303734,
#  'expedition-unknown': 6.232599394662039,
#  'hangar-1-the-ufo-files': 5.658470494406563,
#  'the-increasingly-poor-decisions-of-todd-margaret': 7.855260903494698,
#  'united': 9.204989869253975,
#  'united-states-of-tara': 9.090043794541131,
#  'orange-is-the-new-black': 7.807314927237374,
#  'wentworth': 10,
#  'brooklyn-nine-nine': 8.37434586904999,
#  'parks-and-recreation': 9.494262127649215,
#  'happyish': 8.765162755572605,
#  'misfits': 8.964090522031604,
#  'haven': 8.520659517797624,
#  'extant': 6.568707505563148,
#  'legends': 6.805474880532548,
#  'eye-candy': 5.15681539263044,
#  'any-human-heart': 8.935229301452637,
#  'slings-and-arrows': 10,
#  'copper': 7.294826501375669,
#  'john-adams': 10,
#  'please-like-me': 10,
#  'bosch': 9.644129555740635,
#  'turn': 8.722291068425253,
#  'to-the-ends-of-the-earth': 10,
#  'outlander': 8.456004417588558,
#  'grantchester': 7.680278164999825,
#  'deutschland-83': 9.562913194879307,
#  'big-love': 8.90423093523298,
#  'blue-bloods': 8.005443436758858,
#  'ncis': 8.60954722205361,
#  'ghost-whisperer': 8.45086237740895,
#  'sleepy-hollow': 9.288256440843853,
#  'law-order': 8.92970229629287,
#  'terminator-the-sarah-connor-chronicles': 8.941608025687081,
#  'death-in-paradise': 9.049907452719552,
#  'emily-owens-md': 8.155898434775215,
#  'ripper-street': 7.637259823935372,
#  'a-place-to-call-home': 8.197799112889673,
#  '19-2': 8.526303086962017,
#  'sirens': 7.493207159496488,
#  'gravity-falls': 10,
#  'dog-with-a-blog': 5.0160339533627685,
#  'sam-cat': 6.999267918722969,
#  'liv-and-maddie': 8.958032471793038,
#  'girl-meets-world': 7.948969005403064,
#  'breadwinners': 4.551851136343819,
#  'gravity': 10,
#  'monroe': 8.11167968265594,
#  'the-secret-life-of-marilyn-monroe': 8.11167968265594,
#  'reign': 6.665372740320798,
#  'fresh-off-the-boat': 8.266044874368987,
#  'backstrom': 8.28092135963859,
#  'miss-guided': 5.144534451620919,
#  'the-black-donnellys': 8.988548460460844,
#  'due-south': 10,
#  'young-justice': 9.877319063459122,
#  'the-carrie-diaries': 6.749151994311619,
#  'the-originals': 8.007342935918452,
#  'wallander': 8.74808477220081,
#  'gary-unmarried': 7.2800645419529495,
#  'my-own-worst-enemy': 8.29154061651849,
#  'the-bill-engvall-show': 3.6583074160984577,
#  'southland': 10,
#  'summer-heights-high': 9.657347066061837,
#  'nikita': 7.6387577161684135,
#  'leverage': 9.839740140097481,
#  'the-lying-game': 7.657760960715157,
#  'star-crossed': 8.189029594044108,
#  'the-100': 7.450989278424687,
#  'inspector-george-gently': 9.562788254874093,
#  'single-handed': 9.811487129756381,
#  'messiah': 9.805429867335727,
#  'braquo': 8.37182923725673,
#  'edderkoppen': 8.672487122671944,
#  'the-shadow-line': 9.932381213212214,
#  'the-field-of-blood': 7.994554224468412,
#  'endeavour': 10,
#  'anno-1790': 8.714285714285714,
#  'code-37': 9.65994153703962,
#  'transporter-the-series': 7.565572284516834,
#  'the-americans': 9.80600487239777,
#  'shetland': 9.210671765463692,
#  'xiii': 8.368218626294816,
#  'dicte': 8.780561787741524,
#  'weissensee': 10,
#  'salamander': 9.660523755209786,
#  'crossing-lines': 8.376727158682687,
#  'survivor': 7.753849710736955,
#  'what-remains': 7.806079796382359,
#  'peaky-blinders': 9.769790619138687,
#  'the-escape-artist': 7.461008698599678,
#  'hinterland': 7.919600753993778,
#  'no-limit': 9.66251025881086,
#  'fargo': 9.731299733810587,
#  'state-of-play': 10,
#  'the-honourable-woman': 8.787999620891753,
#  'chasing-shadows': 9.414512021200997,
#  'place-of-execution': 8.989591780162993,
#  'the-man-in-the-high-castle': 7.744073799678257,
#  'jordskott': 10,
#  'code-of-a-killer': 9.32939340954735,
#  '100-code': 8.157737118857247,
#  'black-work': 8.159176213400704,
#  'the-brokenwood-mysteries': 8.767681409442234,
#  'modus': 8.407798630850655,
#  'rebus': 8.158088071005684,
#  'lewis': 10,
#  'a-touch-of-frost': 10,
#  'rubicon': 9.679319722311837,
#  'frozen-planet': 10,
#  'anzac-girls': 8.26105590547834,
#  'superjail-': 8.157379014151436,
#  'cowboy-bebop': 10,
#  'meteor': 9.159225804465157,
#  'murder-she-wrote': 9.131505829947335,
#  'the-outer-limits': 9.486826601482573,
#  'animorphs': 7.656217438834053,
#  'freakazoid-': 9.660590989249092,
#  'law-order-criminal-intent': 8.798513401719859,
#  'monk': 9.504794601632767,
#  'gotham': 8.875947483354231,
#  'retired-at-35': 5.079227992466517,
#  'neverland': 5.825767062959216,
#  'vicious': 6.6029091108412965,
#  'z-nation': 8.259423066699314,
#  'defiance': 8.350668848251283,
#  'orphan-black': 8.672597476414271,
#  'hemlock-grove': 8.194053559808687,
#  'almost-human': 9.794091834785034,
#  'the-magicians': 7.44793330642568,
#  'conviction': 8.202608661046103,
#  'little-britain': 8.346173376069032,
#  'dora-the-explorer': 3.9073518344334186,
#  'hannah-montana': 6.489137284415108,
#  'inspector-gadget': 9.793578011648995,
#  'republic-of-doyle': 9.111159621895133,
#  'masters-of-horror': 8.159382207053048,
#  'hart-of-dixie': 8.188401085989815,
#  'lost-in-space': 7.211810824028531,
#  'defying-gravity': 8.514646966116768,
#  'silicon-valley': 9.578257837749662,
#  'the-tudors': 8.601980904170444,
#  'penn-teller-bullshit': 9.532192570822579,
#  'funny-or-die-presents': 5.158056599753243,
#  'flashpoint': 10,
#  'white-collar': 9.29952263046097,
#  'hell-on-wheels': 9.15243421282087,
#  'the-secret-life-of-the-american-teenager': 5.918006061372302,
#  'nip-tuck': 9.202060595012846,
#  'lone-star': 6.659595353262764,
#  'titanic': 8.278416497366768,
#  'drawn-together': 6.567914254324776,
#  'anger-management': 7.594262897194205,
#  '1600-penn': 4.861012513296944,
#  'marvin-marvin': 2.8284173238845094,
#  'legit': 10,
#  'teen-titans-go-': 5.151507718222481,
#  'together': 6.567914254324776,
#  'star-trek-the-animated-series': 9.13071234112694,
#  'planet-of-the-apes': 8.359884793417795,
#  'marco-polo': 8.227386610848562,
#  'the-indian-doctor': 10,
#  'red-oaks': 6.991586866832914,
#  'the-pacific': 8.129617503250888,
#  'todd-and-the-book-of-pure-evil': 10,
#  '3rd-rock-from-the-sun': 10,
#  'teen-wolf': 9.070116727011545,
#  'new-girl': 7.0935782539338215,
#  'blade-the-series': 8.535016877310616,
#  'police-squad-': 10,
#  'neverwhere': 8.45808091844831,
#  'birds-of-prey': 8.652340275900704,
#  'mutant-x': 6.659777505057198,
#  'alfred-hitchcock-presents': 10,
#  'boston-legal': 10,
#  '30-rock': 9.261303396268923,
#  'going-postal': 8.933839921827438,
#  'cold-case': 9.319739841279528,
#  'the-hollow-crown': 8.529936177389962,
#  'new-tricks': 10,
#  'poldark': 9.338171042405165,
#  'damages': 9.804699399130683,
#  'last-man-standing': 8.32948132923671,
#  'terriers': 10,
#  'mad-dogs': 8.944790840148926,
#  'magic-city': 7.391058531261625,
#  'chosen': 9.676346165793282,
#  'crash': 10,
#  'the-leftovers': 7.481154329045315,
#  'the-knick': 9.839700127240294,
#  'kingdom': 9.98337588183239,
#  'the-last-kingdom': 9.951654430853957,
#  'louie': 8.660698277609688,
#  'robocop': 5.283855778830391,
#  'superman': 9.34719329561506,
#  'lois-clark-the-new-adventures-of-superman': 9.434299960172265,
#  'robocop-prime-directives': 5.283855778830391,
#  'the-golden-palace': 8.159327370779854,
#  'detroit-1-8-7': 8.880547758132693,
#  'star-trek-enterprise': 8.350495979268715,
#  'dirty-jobs': 10,
#  'dharma-greg': 8.824100993928454,
#  'mythbusters': 10,
#  'carrier': 10,
#  'mad-about-you': 9.406920296805245,
#  'nash-bridges': 8.661630971091133,
#  'no-ordinary-family': 7.3831277698665465,
#  'big-shots': 10,
#  'the-mob-doctor': 6.791353566305977,
#  'the-moment': 5.817777656373523,
#  'matlock': 9.330177806672594,
#  'masterchef': 5.905117852347237,
#  'the-big-c': 8.663630826132637,
#  'switched-at-birth': 8.258352938152495,
#  'nathan-for-you': 10,
#  'the-profit': 6.158741814749581,
#  'big-time-in-hollywood-fl': 10,
#  'childrens-hospital': 10,
#  'buck-rogers-in-the-25th-century': 8.755868394034248,
#  'green-acres': 8.879924024854386,
#  'ufo': 10,
#  'quatermass-ii': 8.658521039145333,
#  'hammer-house-of-horror': 8.255073506491524,
#  'quatermass-and-the-pit': 10,
#  'the-defenders': 7.717035157339913,
#  'scandal': 5.804913446101175,
#  'frankie': 8.458397479284375,
#  'grace-and-frankie': 8.294814041682653,
#  'unreal': 9.65730653490339,
#  'shogun': 10,
#  'tin-man': 7.4407057989211305,
#  'prohibition': 8.65491805757795,
#  'alice': 7.374498571668352,
#  'show-me-a-hero': 9.374520833151681,
#  'space-1999': 8.534723495301744,
#  'the-pillars-of-the-earth': 8.100839912117301,
#  'friday-the-13th-the-series': 9.488742056347075,
#  'sanford-and-son': 10,
#  'she-wolf-of-london': 8.156558377402169,
#  'the-strain': 7.38789313180106,
#  'the-riches': 9.658786160605294,
#  'journeyman': 9.167601449148995,
#  'the-doctor-blake-mysteries': 9.564917809622628,
#  'the-time-of-our-lives-': 7.411096436636788,
#  'make-me-a-supermodel': 7.154087884085518,
#  'drop-dead-diva': 8.113789378822624,
#  'highlander': 9.806212357112338,
#  'inspector-morse': 9.775615026080418,
#  'call-the-midwife': 9.898634073113191,
#  'monarch-of-the-glen': 9.413289410727364,
#  'keeping-up-appearances': 9.158457619803292,
#  'pride-and-prejudice': 10,
#  'kingdom-hospital': 8.514090810503276,
#  'beverly-hills-90210': 9.202636317601279,
#  'greg-the-bunny': 10,
#  'becker': 10,
#  'spin-city': 8.488680544353667,
#  'home-improvement': 9.113544284523307,
#  'coach': 10,
#  'airwolf': 9.457438438657729,
#  'married-with-children': 10,
#  'wings': 10,
#  'andy-richter-controls-the-universe': 10,
#  'the-guardian': 9.65849767412458,
#  'the-smurfs': 10,
#  'beavis-and-butt-head': 10,
#  'pinky-and-the-brain': 10,
#  'kenan-kel': 10,
#  'austin-ally': 5.924081666128975,
#  'the-bold-and-the-beautiful': 7.5016548065912145,
#  'walker-texas-ranger': 8.991870108104887,
#  'days-of-our-lives': 9.15929923738752,
#  'restless': 8.660479886191231,
#  'my-name-is-earl': 9.63419805254255,
#  'the-golden-girls': 10,
#  'married': 10,
#  'futurama': 10,
#  'catdog': 9.784141404288155,
#  'everybody-loves-raymond': 7.360133225577218,
#  'george-lopez': 8.656877858298165,
#  'grounded-for-life': 9.658279282706124,
#  'danger-mouse': 10,
#  'jag': 8.226378100258962,
#  'according-to-jim': 8.211043264958764,
#  'saved-by-the-bell': 7.835575603303455,
#  'undeclared': 9.084224769047328,
#  'the-king-of-queens': 8.805417845401857,
#  'the-passing-bells': 6.947781562805175,
#  'the-great-war': 10,
#  'midsomer-murders': 9.001228978293282,
#  'fear-the-walking-dead': 6.926903111594063,
#  'john-from-cincinnati': 9.975236597515288,
#  'in-treatment': 10,
#  'flight-of-the-conchords': 9.335368655976794,
#  'kirstie': 8.656727177756173,
#  'reaper': 8.528902871268135,
#  'robin-hood': 7.310739925929478,
#  'lost-in-austen': 9.32025434857323,
#  'bones': 8.38541179384504,
#  'the-casual-vacancy': 6.673439843314034,
#  'outsourced': 10,
#  'when-calls-the-heart': 8.329586051759264,
#  'idiot': 10,
#  'an-idiot-abroad': 10,
#  '1066-the-battle-for-middle-earth': 5.992064657665433,
#  'black-books': 10,
#  'my-little-pony-friendship-is-magic': 9.754548966544014,
#  'falling-skies': 6.8444456963312055,
#  'allen-gregory': 5.7949155398777545,
#  'the-assets': 9.034175259726387,
#  'the-kill-point': 6.9086497851780475,
#  'the-jinx-the-life-and-deaths-of-robert-durst': 9.322981857118151,
#  'the-4400': 7.82400225517445,
#  'waking-the-dead': 8.387477955260835,
#  'sledge-hammer': 10,
#  'the-thorn-birds': 10,
#  'baywatch': 7.94372797012329,
#  'baretta': 9.032958212352934,
#  'stargate-sg-1': 9.149564078415683,
#  'rick-and-morty': 10,
#  'outcasts': 6.6796787806919635,
#  'joey': 6.852051312582833,
#  'bella-and-the-bulldogs': 5.906334740774971,
#  'persons-unknown': 7.339284027015769,
#  'dead-set': 9.25005384172712,
#  'north-and-south': 10,
#  'the-sweeney': 10,
#  'whatever-happened-to-the-likely-lads': 10,
#  'rich-man-poor-man-book-ii': 9.65841804231916,
#  'the-world-at-war': 10,
#  'the-fall': 8.466732155936104,
#  'the-dresden-files': 8.614348063393244,
#  'weird-science': 10,
#  'the-10th-kingdom': 9.537485940115792,
#  'dracula': 7.730189950125557,
#  'bitten': 6.366721970694405,
#  'black-sails': 9.051878278662844,
#  'bag-of-bones': 6.296864754813058,
#  'missing': 8.418020112173897,
#  'the-missing': 8.550007319250026,
#  'the-day-of-the-triffids': 6.127779315766833,
#  'the-job': 10,
#  'trinity': 9.661257130759102,
#  'atlantis': 8.977815210600912,
#  'jane-eyre': 10,
#  'stargate-atlantis': 8.904083542357709,
#  'rabbids-invasion': 6.988730135418119,
#  'star-vs-the-forces-of-evil': 10,
#  'exile': 10,
#  'crisis': 6.316828750428699,
#  'crossbones': 6.708287643250964,
#  'duckman': 10,
#  'the-young-ones': 10,
#  'harvey-birdman-attorney-at-law': 10,
#  'lizzie-mcguire': 9.027390213755817,
#  'lilo-stitch': 9.658531529562813,
#  'broken-trail': 10,
#  'the-time-tunnel': 9.19035802568708,
#  'mcmillan-wife': 7.620753628867012,
#  'the-honeymooners': 10,
#  'ellery-queen': 10,
#  'f-troop': 9.66278110231672,
#  'taxi': 9.649622780936104,
#  'til-death': 7.159032208578926,
#  'the-rockford-files': 9.927595288412912,
#  'get-smart': 10,
#  'voyage-to-the-bottom-of-the-sea': 9.271782834189278,
#  'mission-impossible': 10,
#  'the-big-valley': 9.294480187552315,
#  'shark-tank': 8.287238114840024,
#  'i-love-lucy': 10,
#  'amazing-stories': 8.161653382437569,
#  'american-idol': 6.039742683228991,
#  'american-dreams': 10,
#  'the-roosevelts-an-intimate-history': 10,
#  'the-tonight-show-starring-jimmy-fallon': 6.7569017001560745,
#  'maude': 9.245062487465994,
#  'the-civil-war': 10,
#  'rhoda': 8.658746106284005,
#  'hawaii-five-o': 10,
#  'the-ben-stiller-show': 8.158088547842842,
#  'lucky-louie': 9.25820871080671,
#  'the-wrong-mans': 9.297140938895089,
#  'mildred-pierce': 6.847355706351143,
#  'comanche-moon': 8.214521483769492,
#  'the-cape': 6.903748376028878,
#  'the-awesomes': 6.658270699637276,
#  'power-rangers-samurai': 8.658628804343087,
#  'forever-knight': 10,
#  'weeds': 7.7873830958775105,
#  'the-adventures-of-the-galaxy-rangers': 9.32398273831322,
#  'the-universe': 10,
#  'cavemen': 3.1585191317967,
#  'generation-kill': 10,
#  'survivorman': 10,
#  'regular-show': 10,
#  'henry-danger': 8.386901935973725,
#  'jamaica-inn': 7.657503468649727,
#  'mr-bean': 10,
#  'one-foot-in-the-grave': 9.780008656638008,
#  'not-going-out': 8.355532223837717,
#  'skins': 10,
#  'last-of-the-summer-wine': 7.673216683523995,
#  'rules-of-engagement': 9.358308369772775,
#  '2-broke-girls': 6.951672220063957,
#  '8-out-of-10-cats': 9.156659466879708,
#  'mock-the-week': 9.857620293753486,
#  'the-royle-family': 10,
#  'the-inbetweeners': 10,
#  'would-i-lie-to-you-': 8.65963636125837,
#  'being-erica': 7.326758884248279,
#  'the-goldbergs': 8.932398319244385,
#  'toast-of-london': 9.48747223899478,
#  'a-to-z': 8.693520409720284,
#  '8-out-of-10-cats-does-countdown': 4.657074792044503,
#  'catastrophe': 10,
#  'as-time-goes-by': 9.061549431937081,
#  'miranda': 8.31440931047712,
#  'children-of-dune': 9.986677351452055,
#  'the-monkees': 9.542904770563519,
#  'daria': 9.241542520977202,
#  'the-tunnel': 8.645771367209298,
#  'revolution': 6.025537363602465,
#  '1864': 8.65651307787214,
#  'doctor-foster': 7.009074368319668,
#  'the-kennedys': 9.653136593954903,
#  'chips': 10,
#  'the-bible': 8.327229999360583,
#  '21-jump-street': 8.54717613814713,
#  'doogie-howser-md': 6.992529097057523,
#  'identity': 8.784293515341622,
#  'running-wilde': 8.491796675182524,
#  'body-of-proof': 7.236642913212851,
#  'the-booth-at-the-end': 8.845776612418039,
#  'big-time-rush': 8.159847123282296,
#  'rush': 8.159847123282296,
#  'sonny-with-a-chance': 6.552596485803997,
#  'wizards-of-waverly-place': 9.162866155007727,
#  'the-suite-life-on-deck': 8.222122805459158,
#  'luck': 8.594836554912305,
#  'charlie': 8.642503564017158,
#  'good-luck-charlie': 8.60096385683332,
#  'alcatraz': 6.895520326470126,
#  'doomsday-preppers': 10,
#  'the-dead-files': 2.6599782535008014,
#  'star-trek-continues': 7.910339473542712,
#  'bojack-horseman': 10,
#  'the-hard-times-of-rj-berger': 7.910263402121407,
#  'the-diary-of-anne-frank': 10,
#  'little-dorrit': 9.464286000388007,
#  'cranford': 9.770266343676854,
#  'our-mutual-friend': 10,
#  'the-promise': 10,
#  'cadfael': 10,
#  'the-streets-of-san-francisco': 8.840305827912829,
#  'ally-mcbeal': 7.85307029625038,
#  'shoestring': 10,
#  'hetty-wainthropp-investigates': 9.668592793600899,
#  'alleyn-mysteries': 10,
#  'yes-minister': 10,
#  'yes-prime-minister': 10,
#  'the-andromeda-strain': 6.123541842450152,
#  'the-last-enemy': 9.51661375590733,
#  'law-order-uk': 8.370020593915665,
#  'transparent': 8.701764129457018,
#  'mozart-in-the-jungle': 8.959991038346491,
#  'forever': 9.852323611211117,
#  'the-killing': 9.44467178072248,
#  'remember-me': 7.417909009116036,
#  'the-final-cut': 9.453791291373115,
#  'the-thick-of-it': 10,
#  'andromeda': 6.1869690486363,
#  'midnight-man': 9.656354767935616,
#  'the-state-within': 9.329634212312243,
#  'jonathan-creek': 10,
#  'star-wars-the-clone-wars': 9.319281984432576,
#  'clone': 9.2849074678468,
#  'last-tango-in-halifax': 9.118260680855094,
#  'death-comes-to-pemberley': 6.8821084461514905,
#  'bored-to-death': 7.65742574419294,
#  'no-offence': 7.519885753449938,
#  'fear-itself': 7.602389199393135,
#  'the-young-indiana-jones-chronicles': 8.98102635429019,
#  'star-wars-rebels': 8.453297170270389,
#  'rescue-me': 9.079056762513659,
#  'late-night-with-jimmy-fallon': 7.458990723746163,
#  'the-jetsons': 9.656388623373848,
#  'devious-maids': 8.942233686323288,
#  'american-crime': 9.273784596579414,
#  'sex-drugs-rock-roll': 7.660371644156319,
#  'murdoch-mysteries': 8.90380155926659,
#  'the-mindy-project': 8.65865693773542,
#  'labyrinth': 8.406067711966378,
#  'dirty-sexy-money': 7.257063824789864,
#  'king-maxwell': 8.783796651022774,
#  'chicago-pd': 6.653548104422432,
#  'from-dusk-till-dawn-the-series': 6.446470707181899,
#  'finding-carter': 7.319533370790027,
#  'come-fly-with-me': 6.969727636693597,
#  'blood-ties': 8.157507283346993,
#  'clerks': 9.90417514528547,
#  'revenge': 7.81907067980085,
#  'the-almighty-johnsons': 8.68297849382673,
#  'witches-of-east-end': 6.800752450549412,
#  'nurse-jackie': 8.601420542351285,
#  'blood-oil': 9.8107179914202,
#  'lark-rise-to-candleford': 9.54975915636335,
#  'life-unexpected': 7.470309915996732,
#  'the-glades': 7.885473918197746,
#  'rizzoli-isles': 8.991084757305327,
#  'ashes-to-ashes': 9.01545933314732,
#  'citizen-khan': 7.545606000082833,
#  'raines': 10,
#  'janet-king': 6.911601884024483,
#  '5ive-days-to-midnight': 9.204870776524618,
#  'first-wave': 10,
#  'the-tenant-of-wildfell-hall': 9.520201001848491,
#  'all-creatures-great-and-small': 10,
#  'sense-and-sensibility': 8.658523900168282,
#  'chuck': 9.802592925419882,
#  'carlos': 8.940452575683594,
#  'danger-5': 8.860173279898508,
#  'romanzo-criminale': 10,
#  ...}

# %%
sorted_x = sorted(d_notes.items(), key=lambda kv: kv[1])
sorted_x.reverse()

sorted_dict = OrderedDict(sorted_x)

# %%
sorted_x[0:10]
# Out:
# [('smith', 10),
#  ('blott-on-the-landscape', 10),
#  ('off-limits', 10),
#  ('better-man', 10),
#  ('con-man', 10),
#  ('inside-the-human-body', 10),
#  ('kungamordet', 10),
#  ('guys-with-kids', 10),
#  ('up-pompeii-', 10),
#  ('z-rock', 10)]

# %%
keys_l = list(sorted_dict.keys())

# %%
keys_l[:3]
# Out:
# ['smith', 'blott-on-the-landscape', 'off-limits']

# %%
## Getting the truth values
truth_tr = np.array([rating for (uid,iid),rating in train_mat.items()])
truth_te = np.array([rating for uid,iid,rating in test])

prediction_tr = np.array([pred_func_ksvd(u,i, U_ksvd, I_ksvd, u_means, i_means, mean) for (u,i),rating in train_mat.items()])
prediction_te = np.array([pred_func_ksvd(u,i, U_ksvd, I_ksvd, u_means, i_means, mean) for u,i,rating in test])


print("Training Error:")
print("MSE:",  MSE_err(prediction_tr,truth_tr))
print("MAE:",  MAE_err(prediction_tr,truth_tr))
    
print("Test Error:")
print("MSE:",  MSE_err(prediction_te,truth_te))
print("MAE:",  MAE_err(prediction_te,truth_te))
# Out:
# Training Error:
# MSE: 1.5642711576695214
# MAE: 0.799072435618619
# Test Error:
# MSE: 5.645687708445735
# MAE: 1.8053423021007617

# %%
prediction_tr, prediction_te = predictions_NMF(train_mat,test, 100, num_user, num_item)
print("Training Error:")
print("MSE:",  MSE_err(prediction_tr,truth_tr))
print("MAE:",  MAE_err(prediction_tr,truth_tr))
    
print("Test Error:")
print("MSE:",  MSE_err(prediction_te,truth_te))
print("MAE:",  MAE_err(prediction_te,truth_te))
# Out:
# WARNING:tensorflow:From /Users/constancescherer/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/constancescherer/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Training Error:
# MSE: 0.0055299895
# MAE: 0.0055299895
# Test Error:
# MSE: 9.278471711976488
# MAE: 2.358559882439383
