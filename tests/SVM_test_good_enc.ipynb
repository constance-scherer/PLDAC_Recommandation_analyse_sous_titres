# %%
import numpy as np
from utils.preprocessing_cleaned_data import *
from utils.swSets import *
from sklearn import naive_bayes, metrics, svm
from sklearn.model_selection import train_test_split, cross_val_score
import matplotlib.pyplot as plt

# %% [markdown]
# # SVM sur les séries (mais bien encodées maintenant)

# %%
path = "/Vrac/PLDAC_addic7ed/data20"
createCleanedData(path, "/Vrac/PLDAC_addic7ed/cleaned_data20")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-51933c470ce7> in <module>()
#       1 path = "/Vrac/PLDAC_addic7ed/data20"
# ----> 2 createCleanedData(path, "/Vrac/PLDAC_addic7ed/cleaned_data20")
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/preprocessing_cleaned_data.py in createCleanedData(path, new_dir)
#     226 def createCleanedData(path, new_dir):
#     227
# --> 228     removeFilesAndFoldersThatNeedToGo(path)
#     229     filenames= sorted(os.listdir(path))
#     230     path_length = len(path)
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/preprocessing_cleaned_data.py in removeFilesAndFoldersThatNeedToGo(path)
#     102 def removeFilesAndFoldersThatNeedToGo(path):
#     103     getRidOfGrabInfo(path)
# --> 104     getRidOfNonEnglishEpisodes(path)
#     105     removeEmptyFolders(path, removeRoot=True)
#     106
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/preprocessing_cleaned_data.py in getRidOfNonEnglishEpisodes(path)
#      97                     for episode in sorted(os.listdir(season_path)):
#      98                         episode_path = season_path+"/"+episode
# ---> 99                         if not isEnglish(episode_path):
#     100                             os.remove(episode_path)
#     101
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/language_detector.py in isEnglish(path)
#      43     text = f.read()
#      44     f.close()
# ---> 45     language = detect_language(text)
#      46     return language == "english"
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/language_detector.py in detect_language(text)
#      28 def detect_language(text):
#      29
# ---> 30     ratios = _calc_ratios(text)
#      31
#      32     most_rated_language = max(ratios, key=ratios.get)
#
# /users/nfs/Etu6/3520166/PLDAC_Recommandation_analyse_sous_titres-master/utils/language_detector.py in _calc_ratios(text)
#      13     ratios = {}
#      14
# ---> 15     tokens = wordpunct_tokenize(text)
#      16     words = [word.lower() for word in tokens]
#      17
#
# ~/.local/lib/python3.5/site-packages/nltk/tokenize/regexp.py in tokenize(self, text)
#     134         # If our regexp matches tokens, use re.findall:
#     135         else:
# --> 136             return self._regexp.findall(text)
#     137
#     138     def span_tokenize(self, text):
#
# KeyboardInterrupt:

# %%
path = "/Vrac/PLDAC_addic7ed/cleaned_data20"
d_info, d_name = getDicts(path)
d_name
# Out:
# {1: '10___Smallville',
#  2: '122___Malcolm_In_The_Middle',
#  3: '12___Doctor_Who',
#  4: '132___NCIS',
#  5: '15___House',
#  6: '16___Desperate_Housewives',
#  7: '186___American_Dad',
#  8: '2381___Scandal',
#  9: '24___Scrubs',
#  10: '28___Bones',
#  11: '30___Grey_s_Anatomy',
#  12: '3103___House_of_Cards_(2013)',
#  13: '32___Veronica_Mars',
#  14: '366___True_Blood',
#  15: '51___How_I_Met_Your_Mother',
#  16: '57___CSI__Crime_Scene_Investigation',
#  17: '615___The_Good_Wife',
#  18: '66___Ugly_Betty',
#  19: '71___The_Wire',
#  20: '880___Pretty_Little_Liars'}

# %%
corpus = get_corpus(path, texts_as="shows")
X = getTfidfSparseMat(corpus, my_stopwords = stopwords_set)

# %%
Y = list(d_name.keys())

# %%
type(Y)
# Out:
# list

# %%
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
def getTfidfDataFrame(corpus, my_stopwords=None, my_tokenizer=None):
    vectorizer = TfidfVectorizer(stop_words = my_stopwords, tokenizer=my_tokenizer)
    X = vectorizer.fit_transform(corpus)
    return pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names()), vectorizer.get_feature_names()

# %%
df, names = getTfidfDataFrame(corpus, stopwords_set)

# %%
coef = lsvm_clf.coef_
for serie in range(0, len(coef)) :
    l = list(coef[serie])
    i = l.index(max(l))
    nomSerie = d_name[serie+1]
    print('Pour la série '+str(nomSerie)+', \n \tle mot le plus important est : '+str(names[i])+'\n')
# Out:
# Pour la série 10___Smallville,
#  	le mot le plus important est : clark
#
# Pour la série 122___Malcolm_In_The_Middle,
#  	le mot le plus important est : malcolm
#
# Pour la série 12___Doctor_Who,
#  	le mot le plus important est : doctor
#
# Pour la série 132___NCIS,
#  	le mot le plus important est : gibbs
#
# Pour la série 15___House,
#  	le mot le plus important est : cuddy
#
# Pour la série 16___Desperate_Housewives,
#  	le mot le plus important est : lynette
#
# Pour la série 186___American_Dad,
#  	le mot le plus important est : francine
#
# Pour la série 2381___Scandal,
#  	le mot le plus important est : liv
#
# Pour la série 24___Scrubs,
#  	le mot le plus important est : turk
#
# Pour la série 28___Bones,
#  	le mot le plus important est : hodgins
#
# Pour la série 30___Grey_s_Anatomy,
#  	le mot le plus important est : dr
#
# Pour la série 3103___House_of_Cards_(2013),
#  	le mot le plus important est : president
#
# Pour la série 32___Veronica_Mars,
#  	le mot le plus important est : veronica
#
# Pour la série 366___True_Blood,
#  	le mot le plus important est : sookie
#
# Pour la série 51___How_I_Met_Your_Mother,
#  	le mot le plus important est : ted
#
# Pour la série 57___CSI__Crime_Scene_Investigation,
#  	le mot le plus important est : grissom
#
# Pour la série 615___The_Good_Wife,
#  	le mot le plus important est : florrick
#
# Pour la série 66___Ugly_Betty,
#  	le mot le plus important est : betty
#
# Pour la série 71___The_Wire,
#  	le mot le plus important est : shit
#
# Pour la série 880___Pretty_Little_Liars,
#  	le mot le plus important est : hanna

# %%
def getTfDataFrame(corpus, my_stopwords=None, my_tokenizer=None):
    vectorizer = CountVectorizer(stop_words = my_stopwords, tokenizer=my_tokenizer)
    X = vectorizer.fit_transform(corpus)
    return pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
df_tf = getTfDataFrame(corpus, stopwords_set)

# %%
d_freq = dict()

# %%
d = df.iloc[0]

# %%
for mot in names :
    d_freq[mot] = d[mot]

# %%
df.iloc[0]
# Out:
# 00                      0.004540
# 000                     0.003265
# 000000                  0.000000
# 00001                   0.000000
# 000b                    0.000000
# 000lbs                  0.000000
# 000mph                  0.000000
# 000th                   0.000000
# 000ths                  0.000000
# 000to                   0.000000
# 001                     0.000194
# 0010                    0.000000
# 0015                    0.000000
# 002                     0.000000
# 003                     0.000000
# 004                     0.000000
# 007                     0.000538
# 007s                    0.000000
# 009                     0.000000
# 00am                    0.000000
# 00in                    0.000000
# 00pm                    0.000000
# 01                      0.000112
# 0100                    0.000000
# 01033                   0.000000
# 010874                  0.000000
# 0110                    0.000000
# 012                     0.000000
# 0121                    0.000000
# 0122                    0.000000
#                           ...
# über                    0.000000
# ü¼à                     0.000000
# üãîµäêçê²ô              0.000000
# ý4                      0.000267
# ýéï24ð                  0.000267
# ýõâ                     0.000267
# þ¼¾                     0.000000
# þ¼¾µú10¼                0.000000
# þ¼¾µú3¼                 0.000000
# þ¼¾µú5¼                 0.000000
# þ¼¾µú6¼                 0.000000
# þ¼¾µú7¼                 0.000000
# þ¼¾µú8¼                 0.000000
# þ¼¾µú9¼                 0.000000
# þèë                     0.000235
# þê                      0.000000
# ÿbueno                  0.000000
# ÿcomo                   0.000000
# ÿhabla                  0.000000
# ÿìì                     0.000267
# įį                      0.000000
# ıä¹ú                    0.000267
# ĸµäô                    0.000267
# ĸîªáë¾èîò               0.000267
# ũ³                      0.000267
# ůèë                     0.000267
# ųöè                     0.000267
# ŵäóäáéíþð²µ½äãµäéúãü    0.000267
# źü³ô¾ªµäñù              0.000267
# 凶器に指紋なし                 0.000000
# Name: 0, Length: 94506, dtype: float64

# %%
nlargest = 20
order = np.argsort(-df_tf.values, axis=1)[:, :nlargest]
result = pd.DataFrame(df_tf.columns[order], 
                      columns=['top{}'.format(i) for i in range(1, nlargest+1)],
                      index=df_tf.index)
result
# Out:
#          top1    top2    top3      top4     top5    top6     top7      top8  \
# 0       clark     lex   gonna      lana    chloe    time     look      lois
# 1     malcolm     mom    look      time      dad   reese    dewey    little
# 2      doctor    time    look     sorry     tell  people     stop    tardis
# 3       gibbs   mcgee    tony     agent     time    boss     tell      look
# 4       house   gonna    time   patient     tell   wrong   people     blood
# 5       gonna    time   sorry      look     tell  little     mean       god
# 6        stan   gonna   steve      look    roger    time      god  francine
# 7   president  olivia   gonna      tell     time  people      liv     house
# 8       gonna      dr    look      time     turk    tell   little      baby
# 9       booth    look      dr     bones  brennan    time   victim      mean
# 10      gonna      dr    time      look     tell    mean    sorry   surgery
# 11  president     sir    time     thank    frank  people     tell     gonna
# 12   veronica   gonna    time       dad     look    tell      guy     night
# 13      gonna    fuck  sookie   vampire      god    time    sorry      tell
# 14        ted  barney   robin  marshall     lily   gonna     guys      look
# 15       look    time     guy     maybe     tell   blood      car     gonna
# 16     alicia   honor   thank  florrick     time   sorry     look     peter
# 17      betty  daniel   gonna      look    sorry    time     mean    little
# 18       shit   gonna    fuck      look  fucking      yo     time      mean
# 19      gonna   hanna     mom      look     tell     ali  spencer      time
#
#       top9    top10    top11      top12    top13   top14   top15       top16  \
# 0     tell   people     help       life    sorry     dad   maybe      little
# 1      god    gonna      hal      sorry     tell    mean    life     francis
# 2     mean      sir     help        bit     life   world  little       hello
# 3    gonna     abby  dinozzo       ziva      guy   phone    dead       maybe
# 4    maybe    heart     look      sorry    cause    life      dr       brain
# 5     love    susan     bree       talk  lynette  people   thank        mike
# 6      dad   hayley    sorry       love     wait    tell  little         day
# 7    cyrus     look     love      sorry    white    pope    huck         job
# 8      god     love   elliot     people    sorry     guy   carla        mean
# 9    gonna     tell   people    hodgins      guy   maybe  little      killed
# 10      um     fine      god       talk  patient  little  people         day
# 11    look     talk    house  underwood   claire   sorry    mean     francis
# 12  little    sorry     mars     school    maybe    mean    girl        help
# 13   blood  fucking     shit      jason     look    love   night      people
# 14    time     love     mean      sorry      god    wait    tell      little
# 15    mean   little    night       dead     body    guys   house       looks
# 16    tell     talk     cary     client       um   diane    mean         eli
# 17     god     tell    thank       love       um   maybe    marc  wilhelmina
# 18    tell   people    money     little      ass     day  police         boy
# 19    mona   alison     mean      maybe    sorry    aria    talk       emily
#
#      top17         top18     top19   top20
# 0     mean          kent    father     son
# 1     boys          wait    people    lois
# 2    human         clara       amy     day
# 3   little          mean      talk   sorry
# 4    means           guy      mean  little
# 5     help          told        um  carlos
# 6    smith        people      life    home
# 7      sir         thank    mellie    talk
# 8     guys          talk    doctor     cox
# 9    sorry        murder      body     god
# 10    baby         thank      wait    stop
# 11  office          help     night    vice
# 12   logan        people    thanks   guess
# 13    tara        little      life    eric
# 14   night           guy      girl    baby
# 15    help        killed  evidence  people
# 16   court         gonna   kalinda  people
# 17      lt          talk     meade    wait
# 18   maybe  motherfucker      talk   gotta
# 19   night           dad      help    wait

# %%
from nltk.tag import pos_tag

# %%
ex1 = 'Claire went to the beach yesterday.'

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(ex1)
sent
# Out:
# [('The', 'DT'),
#  ('President', 'NNP'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('beach', 'NN'),
#  ('yesterday', 'NN'),
#  ('.', '.')]

# %%
ex2 = 'The President went to the beach yesterday.'

# %%
sent = preprocess(ex2)
sent
# Out:
# [('The', 'DT'),
#  ('President', 'NNP'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('beach', 'NN'),
#  ('yesterday', 'NN'),
#  ('.', '.')]

# %%
ex3 = 'The president went to the beach yesterday.'

# %%
sent = preprocess(ex3)
sent
# Out:
# [('The', 'DT'),
#  ('president', 'NN'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('beach', 'NN'),
#  ('yesterday', 'NN'),
#  ('.', '.')]

# %%
ex4 = 'claire went to the beach yesterday.'

# %%
sent = preprocess(ex4)
sent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-66740b78cbb7> in <module>()
# ----> 1 sent = preprocess(ex4)
#       2 sent
#
# NameError: name 'preprocess' is not defined

# %% [markdown]
# <font color='red'> **Problème** : ne reconnait pas les noms propres sur des textes en minuscule.</font>
#
# On peut même pas se dire qu'on enlève les noms propres avant de passer en minuscules parce que les auteurs des sous-titres ne mettent pas forcément les majsucules aux noms. On adore.

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


text = corpus[0]
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="white", stopwords=stopwords_set, colormap='plasma').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white", stopwords=stopwords_set, colormap='plasma')
wordcloud.generate_from_frequencies(frequencies=d_freq)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
